# %%
import pandas as pd
import warnings

warnings.filterwarnings("ignore")

# %%
crime_records = pd.read_csv('../Data/Crime_Records.csv')
len(crime_records)
# Out:
# 898199

# %%
crime_records
# Out:
#              Incident Datetime Incident Date Incident Time  Incident Year  \
# 0       2023/03/13 11:41:00 PM    2023/03/13         23:41           2023
# 1       2023/03/01 05:02:00 AM    2023/03/01         05:02           2023
# 2       2023/03/13 01:16:00 PM    2023/03/13         13:16           2023
# 3       2023/03/13 10:59:00 AM    2023/03/13         10:59           2023
# 4       2023/03/14 06:44:00 PM    2023/03/14         18:44           2023
# ...                        ...           ...           ...            ...
# 898194  2023/03/22 01:30:00 PM    2023/03/22         13:30           2023
# 898195  2023/03/22 12:13:00 AM    2023/03/22         00:13           2023
# 898196  2023/03/21 09:19:00 PM    2023/03/21         21:19           2023
# 898197  2023/03/22 03:28:00 PM    2023/03/22         15:28           2023
# 898198  2023/03/21 05:42:00 PM    2023/03/21         17:42           2023
#
#        Incident Day of Week         Report Datetime        Row ID  \
# 0                    Monday  2023/03/13 11:41:00 PM  125373607041
# 1                 Wednesday  2023/03/11 03:40:00 PM  125379506374
# 2                    Monday  2023/03/13 01:17:00 PM  125357107041
# 3                    Monday  2023/03/13 11:00:00 AM  125355107041
# 4                   Tuesday  2023/03/14 06:45:00 PM  125402407041
# ...                     ...                     ...           ...
# 898194            Wednesday  2023/03/22 01:35:00 PM  125685303401
# 898195            Wednesday  2023/03/22 12:13:00 AM  125665206371
# 898196              Tuesday  2023/03/21 10:16:00 PM  125664272000
# 898197            Wednesday  2023/03/22 05:51:00 PM  125687306303
# 898198              Tuesday  2023/03/22 09:40:00 AM  125676707021
#
#         Incident ID  Incident Number   CAD Number  ...   Longitude  \
# 0           1253736        230167874          NaN  ...         NaN
# 1           1253795        236046151          NaN  ...         NaN
# 2           1253571        220343896          NaN  ...         NaN
# 3           1253551        230174885          NaN  ...         NaN
# 4           1254024        230176728          NaN  ...         NaN
# ...             ...              ...          ...  ...         ...
# 898194      1256853        230201949  230811847.0  ... -122.406336
# 898195      1256652        230200838  230810020.0  ... -122.440624
# 898196      1256642        230200800  230803734.0  ... -122.452665
# 898197      1256873        230202486  230812680.0  ... -122.405574
# 898198      1256767        230201450  230811015.0  ... -122.402056
#
#                                                  Point Neighborhoods  \
# 0                                                  NaN           NaN
# 1                                                  NaN           NaN
# 2                                                  NaN           NaN
# 3                                                  NaN           NaN
# 4                                                  NaN           NaN
# ...                                                ...           ...
# 898194   POINT (-122.40633623830558 37.75300402962228)          54.0
# 898195   POINT (-122.44062361999508 37.78899525864335)         102.0
# 898196   POINT (-122.45266472219633 37.70880633652071)          66.0
# 898197  POINT (-122.40557374633903 37.790565236529574)          19.0
# 898198   POINT (-122.40205647302719 37.72127745117722)          91.0
#
#         ESNCAG - Boundary File  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 898194                     NaN
# 898195                     NaN
# 898196                     NaN
# 898197                     NaN
# 898198                     NaN
#
#        Central Market/Tenderloin Boundary Polygon - Updated  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 898194                                                NaN
# 898195                                                NaN
# 898196                                                NaN
# 898197                                                NaN
# 898198                                                NaN
#
#        Civic Center Harm Reduction Project Boundary  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ...                                             ...
# 898194                                          NaN
# 898195                                          NaN
# 898196                                          NaN
# 898197                                          NaN
# 898198                                          NaN
#
#        HSOC Zones as of 2018-06-05 Invest In Neighborhoods (IIN) Areas  \
# 0                              NaN                                 NaN
# 1                              NaN                                 NaN
# 2                              NaN                                 NaN
# 3                              NaN                                 NaN
# 4                              NaN                                 NaN
# ...                            ...                                 ...
# 898194                         3.0                                 NaN
# 898195                         NaN                                 NaN
# 898196                         NaN                                 NaN
# 898197                         NaN                                 NaN
# 898198                         NaN                                 NaN
#
#        Current Supervisor Districts  Current Police Districts
# 0                               NaN                       NaN
# 1                               NaN                       NaN
# 2                               NaN                       NaN
# 3                               NaN                       NaN
# 4                               NaN                       NaN
# ...                             ...                       ...
# 898194                          2.0                       3.0
# 898195                          6.0                       4.0
# 898196                          1.0                       9.0
# 898197                          3.0                       6.0
# 898198                          2.0                       2.0
#
# [898199 rows x 35 columns]

# %%
crime_records = crime_records[['Incident ID', 'Incident Description', 'Incident Datetime', 'Incident Day of Week', 'Incident Category', 'Incident Subcategory', 'Report Datetime', 'Report Type Code','Report Type Description', 'Police District', 'Latitude', 'Longitude', 'Resolution']]
   
# some transformations
crime_records['Incident Datetime'] = pd.to_datetime(crime_records['Incident Datetime'])
crime_records['Report Datetime'] = pd.to_datetime(crime_records['Report Datetime'])
crime_records['Incident Category'] = crime_records['Incident Category'].apply(str)
crime_records['Incident Subcategory'] = crime_records['Incident Subcategory'].apply(str)
crime_records['Incident Description'] = crime_records['Incident Description'].apply(lambda d: d.replace(',', '-') )
crime_records['Incident Category'] = crime_records['Incident Category'].apply(lambda d: d.replace(',', '-') )
crime_records['Incident Subcategory'] = crime_records['Incident Subcategory'].apply(lambda d: d.replace(',', '-') )
crime_records['Incident Category'].fillna('', inplace=True)
crime_records['Incident Subcategory'].fillna('', inplace=True)
crime_records.drop_duplicates(inplace=True)
crime_records.loc[crime_records['Incident Category']=='nan', ['Incident Subcategory', 'Incident Category']] = ''

# %%
crime_records
# Out:
#         Incident ID              Incident Description   Incident Datetime  \
# 0           1253736          Vehicle- Recovered- Auto 2023-03-13 23:41:00
# 1           1253795      Theft- Other Property- >$950 2023-03-01 05:02:00
# 2           1253571          Vehicle- Recovered- Auto 2023-03-13 13:16:00
# 3           1253551          Vehicle- Recovered- Auto 2023-03-13 10:59:00
# 4           1254024          Vehicle- Recovered- Auto 2023-03-14 18:44:00
# ...             ...                               ...                 ...
# 898194      1256853  Shoplifting- Force against Agent 2023-03-22 13:30:00
# 898195      1256652       Theft- Other Property- <$50 2023-03-22 00:13:00
# 898196      1256642                   Found  Property 2023-03-21 21:19:00
# 898197      1256873   Theft- From Building- $200-$950 2023-03-22 15:28:00
# 898198      1256767             Vehicle- Stolen- Auto 2023-03-21 17:42:00
#
#        Incident Day of Week    Incident Category  \
# 0                    Monday    Recovered Vehicle
# 1                 Wednesday        Larceny Theft
# 2                    Monday    Recovered Vehicle
# 3                    Monday    Recovered Vehicle
# 4                   Tuesday    Recovered Vehicle
# ...                     ...                  ...
# 898194            Wednesday              Robbery
# 898195            Wednesday        Larceny Theft
# 898196              Tuesday         Non-Criminal
# 898197            Wednesday        Larceny Theft
# 898198              Tuesday  Motor Vehicle Theft
#
#                  Incident Subcategory     Report Datetime Report Type Code  \
# 0                   Recovered Vehicle 2023-03-13 23:41:00               VS
# 1               Larceny Theft - Other 2023-03-11 15:40:00               II
# 2                   Recovered Vehicle 2023-03-13 13:17:00               VS
# 3                   Recovered Vehicle 2023-03-13 11:00:00               VS
# 4                   Recovered Vehicle 2023-03-14 18:45:00               VS
# ...                               ...                 ...              ...
# 898194           Robbery - Commercial 2023-03-22 13:35:00               II
# 898195          Larceny Theft - Other 2023-03-22 00:13:00               II
# 898196                   Non-Criminal 2023-03-21 22:16:00               II
# 898197  Larceny Theft - From Building 2023-03-22 17:51:00               II
# 898198            Motor Vehicle Theft 2023-03-22 09:40:00               VI
#
#        Report Type Description Police District   Latitude   Longitude  \
# 0           Vehicle Supplement       Out of SF        NaN         NaN
# 1             Coplogic Initial         Mission        NaN         NaN
# 2           Vehicle Supplement       Out of SF        NaN         NaN
# 3           Vehicle Supplement       Out of SF        NaN         NaN
# 4           Vehicle Supplement       Out of SF        NaN         NaN
# ...                        ...             ...        ...         ...
# 898194                 Initial         Mission  37.753004 -122.406336
# 898195                 Initial        Northern  37.788995 -122.440624
# 898196                 Initial       Ingleside  37.708806 -122.452665
# 898197                 Initial         Central  37.790565 -122.405574
# 898198         Vehicle Initial         Bayview  37.721277 -122.402056
#
#                   Resolution
# 0             Open or Active
# 1             Open or Active
# 2             Open or Active
# 3             Open or Active
# 4             Open or Active
# ...                      ...
# 898194  Cite or Arrest Adult
# 898195  Cite or Arrest Adult
# 898196        Open or Active
# 898197        Open or Active
# 898198        Open or Active
#
# [898198 rows x 13 columns]
